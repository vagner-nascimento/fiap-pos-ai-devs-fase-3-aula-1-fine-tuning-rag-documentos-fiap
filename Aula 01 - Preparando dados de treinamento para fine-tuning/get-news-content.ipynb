# %%
#Conexão com o Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from bs4 import BeautifulSoup
import json

def get_news_content(links_file):
    # Carrega o arquivo com os links e retorna uma lista
    with open(links_file, 'r') as file:
        links = set(file.readlines())
    news_contents = []

    for link in links:
        link = link.strip()  # Limpa a URL, se necessário
        print(link)
        response = requests.get(link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Localiza o elemento que contém o conteúdo do artigo
            article_content = soup.find('div', class_='article__content')
            if article_content:
                paragraphs = article_content.find_all('p', class_='paragraph-elevate inline-placeholder vossi-paragraph_elevate')
                # Concatena o texto de todos os parágrafos encontrados
                content = ' '.join(p.get_text(strip=True) for p in paragraphs)
                news_contents.append(content)
                print(content)
            else:
                news_contents.append("Conteúdo não encontrado.")
        else:
            news_contents.append(f"Falha ao extrair o conteúdo da notícia: {response.status_code}")

    # Salva o conteúdo em um arquivo JSON
    with open('/content/drive/MyDrive/Estudos/FIAP - Pos IA para Devs/Fase 3/Fine Tunning/Aula 1/news_contents.json', 'w') as json_file:
        json.dump({"news_content": news_contents}, json_file)

# Chamada da função para extrair os conteúdos
get_news_content('/content/drive/MyDrive/Estudos/FIAP - Pos IA para Devs/Fase 3/Fine Tunning/Aula 1/CNN_Links.txt')
# Out:
# https://edition.cnn.com/2026/07/17/style/rosebush-pruning-costume
# article_content found
#
# https://edition.cnn.com/2026/07/25/india/india-education-minister-resignation-intl
# article_content found
#
# https://edition.cnn.com/2026/06/20/world/video/smerconish-on-iran-this-deal-is-the-worst-outcome-except-for-all-the-others
# https://edition.cnn.com/2026/01/30/world/gallery/people-we-lost-2026
# https://edition.cnn.com/2026/07/22/middleeast/iran-pickaxe-mountain-nuclear-site-explainer-intl-hnk
# article_content found
#
# https://edition.cnn.com/2026/06/22/world/video/keirstarmerresigns
# https://edition.cnn.com/2026/07/21/middleeast/iran-war-israel-sidelines-preparations-intl
# article_content found
#
# https://edition.cnn.com/2026/07/24/sport/lebron-james-chooses-philadelphia
# article_content found
#
# https://edition.cnn.com/2026/07/26/europe/ukraine-civilian-casualties-intl
# article_content found
#
# https://edition.cnn.com/2026/07/27/middleeast/caspian-sea-iran-ukraine-wars-collide-intl
# article_content found
#
# https://edition.cnn.com/2026/07/26/sport/tadej-pogacar-fifth-tour-de-france-title
# article_content found
#
# https://edition.cnn.com/2026/07/13/asia/japan-royal-crisis-women-emperor-ban-intl-hnk
# article_content found
#
# https://edition.cnn.com/2026/07/23/weather/bertha-flood-threat-east-climate-hnk
# article_content found
#
# https://edition.cnn.com/2026/06/08/style/sagrada-familia-barcelona-tower-jesus-christ-intl
# article_content found
#
# https://edition.cnn.com/2026/07/25/americas/mexico-drugs-trump-politicians-intl-latam
# article_content found
#
# https://edition.cnn.com/2026/07/22/style/andrea-marti-photography-kissing-snap
# article_content found
#
# https://edition.cnn.com/2026/07/24/sport/tori-penso-world-cup
# article_content found
#
# https://edition.cnn.com/2026/07/15/style/erling-haaland-lotw-glamour
# article_content found
#
# https://edition.cnn.com/2026/06/04/style/obama-presidential-center-first-look-inside
# article_content found
#
# https://edition.cnn.com/2026/07/25/world/video/berlin-pride-car-ramming-dead-tiergarten-pleitgen-latam-intl
# https://edition.cnn.com/2026/07/23/middleeast/saudi-us-nuclear-deal-arms-race-intl
# article_content found
#
# https://edition.cnn.com/2026/07/21/style/miami-skyline-skyscraper-boom
intl
# article_content found
#
# https://edition.cnn.com/2026/07/27/weather/wisconsin-tornado-great-lakes-midwest-severe-storms-climate
# article_content found
#
# https://edition.cnn.com/2026/07/27/travel/summer-travel-high-prices-loyalty-points
# article_content found
#
# https://edition.cnn.com/2026/07/24/americas/venezuela-gold-earthquakes-intl-latam
# article_content found
#
# https://edition.cnn.com/2026/07/25/travel/uk-pubs-closing-genz-running-scli-intl
# article_content found
#
# https://edition.cnn.com/2026/07/25/sport/kyle-shanahan-car-accident-49ers
# article_content found
#
# https://edition.cnn.com/2026/07/22/americas/nicaragua-daniel-ortega-elections-us-latam-intl
# article_content found
#
# https://edition.cnn.com/2026/07/27/world/live-news/france-spain-wildfires-evacuations
# https://edition.cnn.com/2026/07/27/world/video/climate-europe-anderosn-intv-0727-10a-seg2-ctw-cnni-world-fast
# https://edition.cnn.com/2026/06/22/world/video/colombia-election-tigre-de-la-espriella-lead-tapper
# https://edition.cnn.com/2026/07/27/world/video/climate-europe-myrivili-intv-0727-10a-seg2-ctw-cnni-world-fast
# https://edition.cnn.com/2026/07/27/world/video/berlin-pride-attack-suspect-shot-dead-police-operation
# https://edition.cnn.com/2026/07/26/world/video/fungi-leather-farm-indonesia-transformers-hkn-spc
# https://edition.cnn.com/2026/07/23/asia/china-landslide-death-latam-intl
# article_content found
#
# https://edition.cnn.com/2026/07/20/middleeast/israel-far-right-settlements-gaza-intl
# article_content found
#
# https://edition.cnn.com/2025/10/18/travel/travel-news-nazi-underground-city
# article_content found
#
# https://edition.cnn.com/2026/07/26/asia/asia-gray-divorces-longevity-women-intl-hnk-dst
# article_content found
#
# https://edition.cnn.com/2026/07/23/tech/china-ai-moonshot-kimi-explainer-intl-hnk
# article_content found
#
# https://edition.cnn.com/2026/07/24/asia/china-philippines-south-china-sea-scarborough-intl-hnk
# article_content found
#
# https://edition.cnn.com/2026/07/27/europe/climbers-dead-mount-elbrus-scli-intl
# article_content found
#
# https://edition.cnn.com/2026/07/13/africa/ethiopian-migrants-saudi-arabia-death-row-intl
# article_content found
#
# https://edition.cnn.com/2026/06/21/world/video/trump-vance-iran-digvid
# https://edition.cnn.com/2026/07/24/europe/cap-ferret-peninsula-evacuated-intl
# article_content found
#
# https://edition.cnn.com/2026/07/24/middleeast/west-bank-settler-palestinian-clashes-military-operation-intl
# article_content found
#
# https://edition.cnn.com/2026/07/24/tech/south-korea-sk-hynix-divorce-ruling-intl-hnk
# article_content found
#
# https://edition.cnn.com/2026/04/19/world/video/north-korea-family-escape-digvid
# https://edition.cnn.com/2026/07/20/americas/guyana-shipwreck-intl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1939/2406674669.py in <cell line: 0>()
#      35
#      36 # Chamada da função para extrair os conteúdos
# ---> 37 get_news_content('/content/drive/MyDrive/Estudos/FIAP - Pos IA para Devs/Fase 3/Fine Tunning/Aula 1/CNN_Links.txt')
#
# /tmp/ipykernel_1939/2406674669.py in get_news_content(links_file)
#      12         link = link.strip()  # Limpa a URL, se necessário
#      13         print(link)
# ---> 14         response = requests.get(link)
#      15         if response.status_code == 200:
#      16             soup = BeautifulSoup(response.text, 'html.parser')
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1089         else:
#    1090             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091                 data = self.read(amt=amt, decode_content=decode_content)
#    1092
#    1093                 if data:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     978                 return self._decoded_buffer.get(amt)
#     979
# --> 980         data = self._raw_read(amt)
#     981
#     982         flush_decoder = amt is None or (amt != 0 and not data)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/response.py in _raw_read(self, amt, read1)
#     901         fp_closed = getattr(self._fp, "closed", False)
#     902
# --> 903         with self._error_catcher():
#     904             data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905             if amt is not None and amt != 0 and not data:
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     139             raise RuntimeError("generator didn't yield") from None
#     140
# --> 141     def __exit__(self, typ, value, traceback):
#     142         if typ is None:
#     143             try:
#
# KeyboardInterrupt:
